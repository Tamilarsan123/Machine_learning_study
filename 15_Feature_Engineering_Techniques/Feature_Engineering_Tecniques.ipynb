# %% [markdown]
# ### Feature Engineering
#
# Whatever you do wih features, we call it as Feature Engineering.
#
# * Feature Elimination    - dropping the features.
# * Feature Addition       - adding some features.
# * Feature Transformation - transforming the given feature values into an another scale - Log Tranformation, Sqrt Transformation..
# * Feature Selection      - deciding which features are important out of many features and choosing that features for model building.

# %% [markdown]
# #### Feature Selection Techniques
#
# * sklearn - SelectFromModel
# * sklearn - RFE(ie,Recursive Feature Elimination)

# %% [markdown]
# ## 1.Import Necessariy Libraries

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel,RFE

from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score

from sklearn.datasets import load_breast_cancer

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Import Dataset

# %%
cancer_data = load_breast_cancer()

# %%
cancer_data_df = pd.DataFrame(cancer_data.data,columns=cancer_data.feature_names)
cancer_data_df["Target"] = cancer_data.target
cancer_data_df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %% [markdown]
# ## 3.Data undersatnding

# %%
cancer_data_df.shape
# Out:
# (569, 31)

# %%
cancer_data_df.dtypes
# Out:
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                 float64
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# ...

# %%
cancer_data_df.isna().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# Target                     0
# dtype: int64

# %% [markdown]
# ## 4.Data Preppuration

# %%
X = cancer_data_df.drop(labels="Target",axis=1)
y = cancer_data_df.Target

# %%
X.shape,y.shape
# Out:
# ((569, 30), (569,))

# %% [markdown]
# ## 5.Model Building

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.20,shuffle=True,stratify=y)

# %%
x_train.shape,y_train.shape
# Out:
# ((455, 30), (455,))

# %%
x_test.shape,y_test.shape
# Out:
# ((114, 30), (114,))

# %% [markdown]
# ## 6.Model Training || 7.Model Testing || 8.Model Evaluation

# %%
rf_model = RandomForestClassifier(max_depth=7)
rf_model.fit(x_train,y_train)

y_pred_test = rf_model.predict(x_test)

print("Accuracy_score  :",round(accuracy_score(y_test,y_pred_test),4))
print("Precision_score :",round(precision_score(y_test,y_pred_test),4))
print("Recall_score    :",round(recall_score(y_test,y_pred_test),4))
print("Confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]

# %% [markdown]
# ### SelectFromModel

# %%
select_feature_model = SelectFromModel(estimator=rf_model,max_features=12)
select_feature_model.fit(x_train,y_train)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(max_depth=7), max_features=12)

# %%
select_feature_model.get_support()
# Out:
# array([False, False,  True,  True, False, False, False,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True, False,  True,  True, False, False,  True,
#         True, False, False])

# %%
cancer_data.feature_names[select_feature_model.get_support()]
# Out:
# array(['mean perimeter', 'mean area', 'mean concave points', 'area error',
#        'worst radius', 'worst perimeter', 'worst area', 'worst concavity',
#        'worst concave points'], dtype='<U23')

# %%
len(cancer_data.feature_names[select_feature_model.get_support()])
# Out:
# 9

# %%
selected_feature_x_test = select_feature_model.transform(x_test)
selected_feature_x_train= select_feature_model.transform(x_train)

# %%
selected_feature_x_test.shape,selected_feature_x_train.shape
# Out:
# ((114, 9), (455, 9))

# %%
def runRandomForestClassifier(x_train,x_test,y_train,y_test):
    rf_model = RandomForestClassifier(max_depth=7)
    rf_model.fit(x_train,y_train)
    
    y_pred_test = rf_model.predict(x_test)
    
    print("Accuracy_score  :",round(accuracy_score(y_test,y_pred_test),4))
    print("Precision_score :",round(precision_score(y_test,y_pred_test),4))
    print("Recall_score    :",round(recall_score(y_test,y_pred_test),4))
    print("Confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))

# %%
# %%time
runRandomForestClassifier(x_train,x_test,y_train,y_test)
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 188 ms
# Wall time: 206 ms

# %%
# %%time
runRandomForestClassifier(selected_feature_x_train,selected_feature_x_test,y_train,y_test)
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 156 ms
# Wall time: 171 ms

# %% [markdown]
# ## 2nd Technique RFE

# %%
ref_feature_selection = RFE(estimator= RandomForestClassifier(),n_features_to_select=12)
ref_feature_selection.fit(x_train,y_train)
# Out:
# RFE(estimator=RandomForestClassifier(), n_features_to_select=12)

# %%
ref_feature_selection.get_support()
# Out:
# array([ True, False,  True,  True, False, False,  True,  True, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True, False, False,
#         True, False, False])

# %%
cancer_data.feature_names[ref_feature_selection.get_support()]
# Out:
# array(['mean radius', 'mean perimeter', 'mean area', 'mean concavity',
#        'mean concave points', 'area error', 'worst radius',
#        'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst concave points'], dtype='<U23')

# %%
len(cancer_data.feature_names[ref_feature_selection.get_support()])
# Out:
# 12

# %%
x_train_rex_feature = ref_feature_selection.transform(x_train)
x_test_rex_feature  = ref_feature_selection.transform(x_test)

# %%
x_train_rex_feature.shape,x_test_rex_feature.shape
# Out:
# ((455, 12), (114, 12))

# %%
# %%time
runRandomForestClassifier(x_train,x_test,y_train,y_test) #30 feature
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 172 ms
# Wall time: 179 ms

# %%
# %%time
runRandomForestClassifier(x_train_rex_feature,x_test_rex_feature,y_train,y_test) #12 feature
# Out:
# Accuracy_score  : 0.9737
# Precision_score : 0.9726
# Recall_score    : 0.9861
# Confusion_matrix:
#  [[40  2]
#  [ 1 71]]
# CPU times: total: 125 ms
# Wall time: 148 ms

# %% [markdown]
# ### 3. Take the Important Features from GradientBoosting and train it within RandomForest Algorithm

# %%
ref_select_gb_model = RFE(estimator = GradientBoostingClassifier(),n_features_to_select=12)
ref_select_gb_model.fit(x_train,y_train)
# Out:
# RFE(estimator=GradientBoostingClassifier(), n_features_to_select=12)

# %%
ref_select_gb_model.get_support()
# Out:
# array([False,  True, False, False, False, False,  True,  True, False,
#        False, False, False, False,  True, False,  True, False, False,
#        False, False,  True,  True,  True,  True,  True, False,  True,
#         True, False, False])

# %%
cancer_data.feature_names[ref_select_gb_model.get_support()]
# Out:
# array(['mean texture', 'mean concavity', 'mean concave points',
#        'area error', 'compactness error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst concavity', 'worst concave points'], dtype='<U23')

# %%
len(cancer_data.feature_names[ref_select_gb_model.get_support()])
# Out:
# 12

# %%
x_train_ref_df_model =  ref_select_gb_model.transform(x_train)
x_test_ref_df_model  = ref_select_gb_model.transform(x_test)

# %%
x_train_ref_df_model.shape,x_test_ref_df_model.shape
# Out:
# ((455, 12), (114, 12))

# %%
runRandomForestClassifier(x_train,x_test,y_train,y_test)
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]

# %%
# %%time
runRandomForestClassifier(x_train_ref_df_model,x_test_ref_df_model,y_train,y_test)
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 156 ms
# Wall time: 161 ms

# %%
# %%time
runRandomForestClassifier(x_train_ref_df_model,x_test_ref_df_model,y_train,y_test)
# Out:
# Accuracy_score  : 0.9649
# Precision_score : 0.9722
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[40  2]
#  [ 2 70]]
# CPU times: total: 156 ms
# Wall time: 162 ms

# %% [markdown]
# ### 4. How to choose the Optimal Number of Features to train my Model?

# %%
def runRandomForestClassifier(x_train,x_test,y_train,y_test):
    rf_model = RandomForestClassifier(max_depth=7)
    rf_model.fit(x_train,y_train)
    
    y_pred_test = rf_model.predict(x_test)
    
    print("Accuracy_score  :",round(accuracy_score(y_test,y_pred_test),4))
    print("Precision_score :",round(precision_score(y_test,y_pred_test),4))
    print("Recall_score    :",round(recall_score(y_test,y_pred_test),4))
    print("Confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))

# %%
for i in range (1,31):
    print("Feature Taken",i)
    ref_model = RFE(estimator=GradientBoostingClassifier(),n_features_to_select=i)
    ref_model.fit(x_train,y_train)
    
    x_train_ref_fs_GDBoost = ref_model.transform(x_train) #ref_fs_GDBoost --> ref model feature selection GreadiandBoosting Classifier
    x_test_ref_fs_GDBoost = ref_model.transform(x_test)

    rf_model = RandomForestClassifier(max_depth=7)
    rf_model.fit(x_train_ref_fs_GDBoost,y_train)
    
    y_pred_test = rf_model.predict(x_test_ref_fs_GDBoost)
    
    print("Accuracy_score  :",round(accuracy_score(y_test,y_pred_test),4))
    print("Precision_score :",round(precision_score(y_test,y_pred_test),4))
    print("Recall_score    :",round(recall_score(y_test,y_pred_test),4))
    print("Confusion_matrix:\n",confusion_matrix(y_test,y_pred_test))
    print("***********************************************************")
# Out:
# Feature Taken 1
# Accuracy_score  : 0.8684
# Precision_score : 0.8519
# Recall_score    : 0.9583
# Confusion_matrix:
#  [[30 12]
#  [ 3 69]]
# ***********************************************************
# Feature Taken 2
# Accuracy_score  : 0.8772
# Precision_score : 0.9028
# Recall_score    : 0.9028
# Confusion_matrix:
#  [[35  7]
#  [ 7 65]]
# ***********************************************************
# Feature Taken 3
# Accuracy_score  : 0.9035
# Precision_score : 0.9178
# Recall_score    : 0.9306
# Confusion_matrix:
#  [[36  6]
#  [ 5 67]]
# ***********************************************************
# Feature Taken 4
# Accuracy_score  : 0.9211
# Precision_score : 0.9091
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[35  7]
#  [ 2 70]]
# ***********************************************************
# Feature Taken 5
# Accuracy_score  : 0.9298
# Precision_score : 0.9211
# Recall_score    : 0.9722
# Confusion_matrix:
#  [[36  6]
#  [ 2 70]]
# ...

# %% [markdown]
# ### We found 22 is the Optimal Number of Features

# %%
ref_model = RFE(estimator=GradientBoostingClassifier(),n_features_to_select=21)
ref_model.fit(x_train,y_train)

x_train_ref_model = ref_model.transform(x_train)
x_test_ref_model  = ref_model.transform(x_test)

# %%
ref_model.get_support()
# Out:
# array([False,  True, False,  True,  True, False,  True,  True, False,
#        False,  True,  True,  True,  True, False,  True, False, False,
#         True, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
cancer_data.feature_names[ref_model.get_support()]
# Out:
# array(['mean texture', 'mean area', 'mean smoothness', 'mean concavity',
#        'mean concave points', 'radius error', 'texture error',
#        'perimeter error', 'area error', 'compactness error',
#        'symmetry error', 'worst radius', 'worst texture',
#        'worst perimeter', 'worst area', 'worst smoothness',
#        'worst compactness', 'worst concavity', 'worst concave points',
#        'worst symmetry', 'worst fractal dimension'], dtype='<U23')

# %%
len(cancer_data.feature_names[ref_model.get_support()])
# Out:
# 21

# %%
runRandomForestClassifier(x_train_ref_df_model,x_test_ref_df_model,y_train,y_test)
# Out:
# Accuracy_score  : 0.6053
# Precision_score : 0.6364
# Recall_score    : 0.875
# Confusion_matrix:
#  [[ 6 36]
#  [ 9 63]]

# %% [markdown]
# # THE END!!!
