# %% [markdown]
# ## 1.Import Necessary Libraries

# %%
import pandas as pd 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error

from sklearn.datasets import fetch_california_housing

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2.Import Dataset

# %%
housing_data = fetch_california_housing()

# %%
housing_data_df = pd.DataFrame(housing_data.data,columns=housing_data.feature_names)
housing_data_df["Target"] = housing_data.target
housing_data_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Target
# ...

# %% [markdown]
# ## 3.Data Understanding

# %%
housing_data_df.shape
# Out:
# (20640, 9)

# %%
housing_data_df.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# Target        0
# dtype: int64

# %%
housing_data_df.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# Target        float64
# dtype: object

# %% [markdown]
# ## 4.Data Prepuration

# %%
x = housing_data_df.drop(labels="Target",axis=1)
y = housing_data_df.Target

# %% [markdown]
# ## 5.Model Building

# %% [raw]
# x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=46,shuffle=True)

# %%
x_train.shape,y_train.shape
# Out:
# ((16512, 8), (16512,))

# %%
x_test.shape,y_test.shape
# Out:
# ((4128, 8), (4128,))

# %%
linear_model     = LinearRegression()
ridge_model      = Ridge(alpha=1.0)
lasso_model      = Lasso(alpha=1.0)
elasticnet_model = ElasticNet(alpha=0.1)

# %% [markdown]
# ## 6.Model Training || 7.Model Testing || 8.Model evaluation

# %%
#Model Training
linear_model.fit(x_train,y_train)
ridge_model.fit(x_train,y_train)
lasso_model.fit(x_train,y_train)
elasticnet_model.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=0.1)

# %%
#Model Testing
linear_model.predict(x_test)
ridge_model.predict(x_test)
lasso_model.predict(x_test)
elasticnet_model.predict(x_test)
# Out:
# array([2.5450631 , 2.36270022, 1.55591727, ..., 1.34177333, 2.71696391,
#        2.7411113 ], shape=(4128,))

# %%
#model slop
print("Linear Model")
print(linear_model.coef_)
print("Ridge Model")
print(ridge_model.coef_)
print("Lasso Model")
print(lasso_model.coef_)
print("Elasticnet Model")
print(elasticnet_model.coef_)
# Out:
# Linear Model
# [ 4.45199036e-01  9.60881411e-03 -1.20225971e-01  6.52416483e-01
#  -6.11698771e-06 -3.97764766e-03 -4.06662648e-01 -4.20551532e-01]
# Ridge Model
# [ 4.45068778e-01  9.61081686e-03 -1.19978074e-01  6.51153189e-01
#  -6.10928813e-06 -3.97732536e-03 -4.06654012e-01 -4.20524986e-01]
# Lasso Model
# [ 1.45582995e-01  5.75903999e-03  0.00000000e+00 -0.00000000e+00
#  -7.75671017e-06 -0.00000000e+00 -0.00000000e+00 -0.00000000e+00]
# Elasticnet Model
# [ 3.85815951e-01  1.31990594e-02 -0.00000000e+00  0.00000000e+00
#   7.69806108e-06 -3.51351956e-03 -2.36112589e-01 -2.30033628e-01]
